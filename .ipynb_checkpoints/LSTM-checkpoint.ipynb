# %% [markdown]
# <h1>Importing...</h1>

# %%
import math 
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import LSTM
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler,Normalizer

# %% [markdown]
# <h1>Importing Data...</h1>

# %%
ahpc_read =pd.read_csv('ahpc.csv')
ahpc=pd.DataFrame(ahpc_read)
ahpc.head()
# Out:
#    S.N.     Date   Open   High    Low    Ltp  % Change       Qty    Turnover
# 0   1.0  44672.0  379.0  397.0  365.0  382.0      2.72   74534.0  27842069.4
# 1   1.0  44672.0  379.0  397.0  365.0  382.0      2.72   74534.0  27842069.4
# 2   2.0  44671.0  388.1  395.0  371.0  371.9     -4.64  108762.0  41534206.9
# 3   2.0  44671.0  388.1  395.0  371.0  371.9     -4.64  108762.0  41534206.9
# 4   3.0  44670.0  394.9  403.0  379.0  390.0      0.65   91503.0  35573369.2

# %% [markdown]
# <h1>arranging data in ascending order by date</h1>

# %%
ahpc=ahpc.reindex(index=ahpc.index[::-1])
ltp=ahpc['Ltp']
miny=ltp[ltp.gt(0)].min(axis=0)
maxy=ltp[ltp.gt(0)].max(axis=0)
print(miny,maxy)
# Out:
# 90.0 775.0

# %% [markdown]
# <h1>Filtering features</h1>

# %%
x=ahpc[["Qty","High","Low","Turnover",]]
# x=nabil[["Max Price "]]
y=ahpc[["Ltp"]]

# trying data normaliztion
# normal=Normalizer()
# x=normal.fit_transform(x)
# y=normal.fit_transform(np.array(y).reshape(-1,1))
# x=(x-minx)/(maxx-minx)
# y=(y-miny)/(maxy-miny)
# y=np.array(y).reshape(-1,1)

#trying data scaling
norm=np.hstack((x,y))
norm=norm[~np.any(norm==0,axis=1)]
x=norm[:,0:4]
y=norm[:,4:5]
scaler=MinMaxScaler(feature_range=(0,1))
x=scaler.fit_transform(x)
y=scaler.fit_transform(y)
norm=np.hstack((x,y))
norm=norm[~np.any(norm==0,axis=1)]
x=norm[:,0:4]
y=norm[:,4:5]
# y[training-9:-400]

# %%
#test 
# x=nabil[["Total Traded Shares","Max Price ","Min. Price","Total Traded Shares"]]
# # x=nabil[["Max Price "]]
# y=nabil["Close Price"]

# x_dataset=x.values
# print(training)


length=len(x)
training=int(0.8*length)
test=int(length-training)
# print(y[y.gt(0)].min(axis=0),y[y.gt(0)].max(axis=0))

# %% [markdown]
# <h1>Splitting data to training and test data</h1>

# %%
x_training_data=x[0:training-1]
y_training_data=y[1:training]
x_test_data=x[training:(training+test)]
y_test_data=y[training+1:(training+test)]
# y_test_data.index = pd.RangeIndex(start=0, stop=448, step=1)
# x_test_data.index = pd.RangeIndex(start=0, stop=448, step=1)
# test_date=nabil["Date"][training:(training+test)-1]
# test_date.index = pd.RangeIndex(start=0, stop=448, step=1)
print(x_test_data.shape)
print(y_test_data[0:2])
# Out:
# (507, 4)
# [[0.0189781 ]
#  [0.03357664]]

# %%
print(x_training_data.shape,x_test_data.shape)
# Out:
# (2025, 4) (507, 4)

# %%
model=Sequential()
model.add(LSTM(250, input_shape=(4,1), return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(10, return_sequences=False))
model.add(Dense(10))
model.add(Dense(1))
# model.add(LSTM(1))

# %%
model.compile(loss='mean_absolute_error',optimizer='ADAM',metrics=['mean_absolute_error'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4, 250)            252000
#
#  lstm_1 (LSTM)               (None, 10)                10440
#
#  dense (Dense)               (None, 10)                110
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 262,561
# Trainable params: 262,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_training_data,y_training_data,epochs=20,batch_size=16)
# ,validation_data=(x_test_data,y_test_data)
# Out:
# Epoch 1/20
# 127/127 [==============================] - 4s 8ms/step - loss: 0.0458 - mean_absolute_error: 0.0458
# Epoch 2/20
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0128 - mean_absolute_error: 0.0128
# Epoch 3/20
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 4/20
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 5/20
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0110
# Epoch 6/20
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0114 - mean_absolute_error: 0.0114
# Epoch 7/20
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0105 - mean_absolute_error: 0.0105
# Epoch 8/20
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0105 - mean_absolute_error: 0.0105
# Epoch 9/20
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0110 - mean_absolute_error: 0.0110
# Epoch 10/20
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0099 - mean_absolute_error: 0.0099
# Epoch 11/20
# 127/127 [==============================] - 2s 13ms/step - loss: 0.0110 - mean_absolute_error: 0.0110
# Epoch 12/20
# 127/127 [==============================] - 1s 11ms/step - loss: 0.0097 - mean_absolute_error: 0.0097
# Epoch 13/20
# 127/127 [==============================] - 1s 11ms/step - loss: 0.0104 - mean_absolute_error: 0.0104
# Epoch 14/20
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0104 - mean_absolute_error: 0.0104
# Epoch 15/20
# 127/127 [==============================] - 2s 12ms/step - loss: 0.0104 - mean_absolute_error: 0.0104
# Epoch 16/20
# 127/127 [==============================] - 1s 11ms/step - loss: 0.0102 - mean_absolute_error: 0.0102
# Epoch 17/20
# 127/127 [==============================] - 2s 12ms/step - loss: 0.0098 - mean_absolute_error: 0.0098
# Epoch 18/20
# 127/127 [==============================] - 2s 12ms/step - loss: 0.0105 - mean_absolute_error: 0.0105
# Epoch 19/20
# 127/127 [==============================] - 1s 11ms/step - loss: 0.0098 - mean_absolute_error: 0.0098
# Epoch 20/20
# 127/127 [==============================] - 2s 12ms/step - loss: 0.0107 - mean_absolute_error: 0.0107

# %%
result=model.predict(x_test_data)
plt.plot(history.history['loss'])
plt.show()
print(result[0])
# Out:
# [0.0058683]

# %%
result_length=len(result)-1
result_plot=result[0:result_length]
print(result_length,result.shape,result_plot.shape)
plt.figure(figsize=(20, 8))
# plt.scatter(range(449),result,c='r',s=5)
# plt.scatter(range(449),y_test_data,c='g',s=5)
plt.plot(range(result_length),result_plot,c='r')
plt.plot(range(result_length),y_test_data,c='g')
plt.show()
# Out:
# 506 (507, 1) (506, 1)

# %%
error_length=len(result_plot)
test_true_data=y_test_data*(maxy-miny)+miny
result_true_data=result_plot*(maxy-miny)+miny
last_error=abs(test_true_data-result_true_data)
print(last_error.sum(axis=0)/error_length)
# Out:
# [18.61563564]

# %%
plt.figure(figsize=(20, 8))
# plt.scatter(range(plot_length),x_data,c='r',s=5)
# plt.scatter(range(plot_length),y_data,c='g',s=5)
plt.plot(range(result_length),result_true_data,c='r')
plt.plot(range(result_length),test_true_data,c='g')
plt.show()

# %%
0.0118*(maxy-miny)+miny
# Out:
# 98.083

# %%
print(maxy,miny)
# Out:
# 775.0 90.0

# %% [markdown]
# <h1>Calculating RMSE</h1>

# %%
last_error=(test_true_data-result_true_data)**2
print(math.sqrt(last_error.sum(axis=0)/error_length))
# RMSE=math.sqrt(last_error)
# print(last_error)
# Out:
# 25.145349103985488

# %%
print(result_true_data[error_length-1])
print(result[error_length]*(maxy-miny)+miny)
# Out:
# [364.3805]
# [364.3805]

# %%
print(test_true_data[error_length-1])
# Out:
# [382.]

# %%
 1-np.sqrt(np.mean(np.square((y_test_data-result[0:-1])/y_test_data)))
# Out:
# 0.43491942708198783

# %%
data=ahpc[["Open","High","Low","Close"]]
